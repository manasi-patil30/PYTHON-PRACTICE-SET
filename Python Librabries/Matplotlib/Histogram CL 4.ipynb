# %% [markdown]
# # Histogram Plot

# %%
import matplotlib.pyplot as plt 
import numpy as np
import random

# %%
X = np.random.randint(10,60,(50))
print(X)
# Out:
# [40 14 21 58 56 43 56 34 50 41 37 40 30 15 51 51 43 47 49 49 45 29 51 37
#  29 32 52 21 33 59 14 34 12 11 29 12 51 22 17 54 46 39 28 43 48 57 18 33
#  20 15]

# %%
Num = [32 ,18, 44, 28 ,26, 35, 35, 39, 41, 49, 31, 15, 25 ,13, 16 ,11, 49, 44 ,18, 12, 37, 20 ,10 ,52,     
       22, 44, 51, 47, 49, 40, 51, 24, 43, 38, 44, 34, 25, 48, 11, 39, 55, 59, 12, 24, 21, 19, 34 ,31,       
       26, 13]
plt.hist(Num)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Y = np.random.randint(20,100,40)
print(Y)
# Out:
# [74 71 72 21 97 71 93 93 30 96 60 38 63 51 32 46 92 24 45 34 99 46 73 81
#  51 75 21 72 96 26 41 56 37 66 53 89 72 98 92 46]

# %%
N = [32, 78, 88, 82, 39, 21, 22, 35, 76, 45 ,30 ,28, 84, 33, 75, 64, 99, 82, 99, 56 ,84, 75, 72, 63,
 69, 30, 43, 57, 48, 78, 37, 50, 76, 67, 66, 29 ,29, 88, 21, 81]

plt.hist(N)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Z = np.random.randint(10,60,45)
print(Z)
# Out:
# [27 20 18 36 58 10 11 18 14 22 19 38 58 40 56 48 54 11 21 22 17 17 34 54
#  23 21 34 18 29 35 34 50 28 46 55 11 52 32 39 27 20 22 52 58 21]

# %%
NA =  [58,26, 14, 51, 16 ,22 ,56 ,42, 19, 19, 38, 18 ,56, 31, 50 ,28 ,16, 55, 19, 37, 27, 43, 49, 31,
       26, 10, 37, 50 ,46, 22, 56, 14, 40, 30, 29, 36, 14, 43, 39, 32, 39, 14, 53, 43, 19]
plt.hist(NA)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]

plt.hist(M, color = "y", edgecolor = "r")
plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",bins =l,  edgecolor = "r")
plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, "auto",(0,100), edgecolor = "r")
plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "b",bins =l,  edgecolor = "r")
plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",  edgecolor = "r", cumulative = -1)
plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y", bins = l, edgecolor = "r",  bottom = 10)             # To change bottom number

plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",bins =l,  edgecolor = "r", align = "left" )           # To give alignment

plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",bins =l,  edgecolor = "r", align = "mid" )

plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",bins =l,  edgecolor = "r", histtype = "step" )   # To change histogram Type

plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",bins =l,  edgecolor = "r", histtype  = "stepfilled" )

plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",bins =l,  edgecolor = "r", histtype  = "barstacked" )

plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",bins =l,  edgecolor = "r", histtype  = "bar" )

plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",bins =l,  edgecolor = "r", orientation = "horizontal")      # For to change orientation

plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",bins =l,  edgecolor = "r", orientation = "vertical" )   # This iss by default

plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",bins =l,  edgecolor = "r", rwidth =0.8 )

plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",bins =l,  edgecolor = "r", log = True)    # To convert into logarithm

plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",bins =l,  edgecolor = "r", label = "Maths" )    # For the label

plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")
plt.legend()
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",bins =l,  edgecolor = "r", label = "Maths" )    # For the label

plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")

plt.axvline(45, color = "b",  label = "line")

plt.legend()
plt.show()

# %%
M = [49, 39, 57, 48, 27 ,55 ,44 ,24, 37, 21, 15, 25, 42 ,34 ,12 ,57, 33, 49, 43, 50 ,28 ,45, 45, 22,
 50, 46, 54, 39, 32, 54 ,19, 52, 12, 38, 52, 26, 13, 21, 42, 34, 33, 52, 23, 43 ,57]
l = [10,20,30,40,50,60]
plt.hist(M, color = "y",bins =l,  edgecolor = "r", label = "Maths" )    # For the label

plt.title("R")
plt.xlabel("Python")
plt.ylabel("NO.")

plt.axvline(45, color = "b",  label = "line")

plt.legend()
plt.grid()
plt.show()
