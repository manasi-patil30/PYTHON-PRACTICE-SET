# %% [markdown]
# # READ CSV

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\\Users\\manas\\Downloads\\cleaned.csv")
df
# Out:
#        Brand                                Product_Description  Screen_Size  \
# 0     Lenovo  Lenovo ThinkPad 14” HD Laptop PC Computer Core...         14.0
# 1       Dell  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6
# 2         HP  NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...         15.6
# 3     Lenovo  2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...         15.6
# 4     Lenovo  2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...         15.6
# ...      ...                                                ...          ...
# 2947    Dell  Dell Latitude 7320 i5-1145G7 8GB 256GB BT5 WiF...         13.3
# 2948     MSI  NEW MSI COMPUTER Sword 15 A12UC-295 Sword15122...         15.6
# 2949    Dell  Dell Precision 5550 Workstation 15 15.6 Laptop...         15.6
# 2950      HP  HP 15 Laptop 15.6" FHD i5-1135G7 8GB RAM 256GB...         15.6
# 2951      HP  3 PCS Karlash 6 Column Undated Appointment Boo...         14.0
#
# ...

# %%
df1 = pd.read_csv("C:\\Users\\manas\\Downloads\\cleaned.csv", nrows = 1)
df1
# Out:
#     Brand                                Product_Description  Screen_Size  \
# 0  Lenovo  Lenovo ThinkPad 14” HD Laptop PC Computer Core...           14
#
#    RAM               Processor                    GPU  \
# 0   16  Intel Core i5 7th Gen.  Intel HD Graphics 520
#
#                        GPU_Type  Resolution                Condition   Price
# 0  Integrated/On-Board Graphics         NaN  Very Good - Refurbished  189.99

# %%
df2 = pd.read_csv("C:\\Users\\manas\\Downloads\\cleaned.csv", nrows=3)
df2
# Out:
#     Brand                                Product_Description  Screen_Size  \
# 0  Lenovo  Lenovo ThinkPad 14” HD Laptop PC Computer Core...         14.0
# 1    Dell  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6
# 2      HP  NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...         15.6
#
#    RAM                Processor                     GPU  \
# 0   16   Intel Core i5 7th Gen.   Intel HD Graphics 520
# 1   64   Intel Core i5 8th Gen.  Intel UHD Graphics 620
# 2    8  Intel Core i5 11th Gen.  Intel Iris Xe Graphics
#
#                        GPU_Type   Resolution                Condition   Price
# 0  Integrated/On-Board Graphics          NaN  Very Good - Refurbished  189.99
# 1  Integrated/On-Board Graphics  1920 x 1080  Very Good - Refurbished  349.99
# 2  Integrated/On-Board Graphics  1920 x 1080                      New  369.95

# %%
df3 = pd.read_csv("C:\\Users\\manas\\Downloads\\cleaned.csv", usecols =["Brand","RAM"])
df3
# Out:
#        Brand RAM
# 0     Lenovo  16
# 1       Dell  64
# 2         HP   8
# 3     Lenovo  Up
# 4     Lenovo  16
# ...      ...  ..
# 2947    Dell   8
# 2948     MSI   8
# 2949    Dell   8
# 2950      HP   8
# 2951      HP   8
#
# [2952 rows x 2 columns]

# %%
df.head(10)
# Out:
#        Brand                                Product_Description  Screen_Size  \
# 0     Lenovo  Lenovo ThinkPad 14” HD Laptop PC Computer Core...         14.0
# 1       Dell  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6
# 2         HP  NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...         15.6
# 3     Lenovo  2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...         15.6
# 4     Lenovo  2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...         15.6
# 5  Microsoft  Microsoft Surface Laptop 5 13.5" - 512GB SSD, ...         13.5
# 6     Lenovo  Lenovo V15 G4 IRU 15.6" Full HD Laptop, i7-135...         15.6
# 7       Dell  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6
# 8  Microsoft  Microsoft Surface Laptop 2 -8th Gen - i5 - 1.7...         13.5
# 9     Lenovo  Lenovo ThinkPad T470 14' LCD i5 Laptop PC 16GB...         14.0
#
#   RAM                Processor                     GPU  \
# 0  16   Intel Core i5 7th Gen.   Intel HD Graphics 520
# ...

# %%
df.tail(10)
# Out:
#           Brand                                Product_Description  \
# 2942         HP  HARMONY Gelish VITAGEL Nail Strengthener LED /...
# 2943     Lenovo  NEW Lenovo 82XF001TUS IdeaPad Slim 5 16IRL8 16...
# 2944     Lenovo  Lenovo ThinkPad T15 Gen 2 15.6" FHD i5-1145G7 ...
# 2945       Dell  New Dell XPS 13 9360 FHD Infinity Touch i5-720...
# 2946  Microsoft  Microsoft 12.4" Surface Laptop Go 2 (Intel Cor...
# 2947       Dell  Dell Latitude 7320 i5-1145G7 8GB 256GB BT5 WiF...
# 2948        MSI  NEW MSI COMPUTER Sword 15 A12UC-295 Sword15122...
# 2949       Dell  Dell Precision 5550 Workstation 15 15.6 Laptop...
# 2950         HP  HP 15 Laptop 15.6" FHD i5-1135G7 8GB RAM 256GB...
# 2951         HP  3 PCS Karlash 6 Column Undated Appointment Boo...
#
#       Screen_Size RAM                Processor                      GPU  \
# 2942         14.0   8   Intel Core i5 6th Gen.    Intel HD Graphics 520
# 2943         16.0  16  Intel Core i7 13th Gen.   Intel Iris Xe Graphics
# ...

# %%
df.ndim
# Out:
# 2

# %%
df4 = pd.read_csv("C:\\Users\\manas\\Downloads\\cleaned.csv", skiprows =[0])
df4
# Out:
#          Lenovo  \
# 0          Dell
# 1            HP
# 2        Lenovo
# 3        Lenovo
# 4     Microsoft
# ...         ...
# 2946       Dell
# 2947        MSI
# 2948       Dell
# 2949         HP
# 2950         HP
#
#      Lenovo ThinkPad 14” HD Laptop PC Computer Core i5 16GB RAM 256GB SSD Windows 10  \
# 0     Dell Latitude 15.6" Laptop Intel Core i5 64GB ...
# 1     NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...
# 2     2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...
# 3     2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...
# 4     Microsoft Surface Laptop 5 13.5" - 512GB SSD, ...
# ...                                                 ...
# 2946  Dell Latitude 7320 i5-1145G7 8GB 256GB BT5 WiF...
# 2947  NEW MSI COMPUTER Sword 15 A12UC-295 Sword15122...
# 2948  Dell Precision 5550 Workstation 15 15.6 Laptop...
# 2949  HP 15 Laptop 15.6" FHD i5-1135G7 8GB RAM 256GB...
# 2950  3 PCS Karlash 6 Column Undated Appointment Boo...
#
# ...

# %%
df5 = pd.read_csv("C:\\Users\\manas\\Downloads\\cleaned.csv", skiprows =[0,3])
df5
# Out:
#          Lenovo  \
# 0          Dell
# 1        Lenovo
# 2        Lenovo
# 3     Microsoft
# 4        Lenovo
# ...         ...
# 2945       Dell
# 2946        MSI
# 2947       Dell
# 2948         HP
# 2949         HP
#
#      Lenovo ThinkPad 14” HD Laptop PC Computer Core i5 16GB RAM 256GB SSD Windows 10  \
# 0     Dell Latitude 15.6" Laptop Intel Core i5 64GB ...
# 1     2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...
# 2     2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...
# 3     Microsoft Surface Laptop 5 13.5" - 512GB SSD, ...
# 4     Lenovo V15 G4 IRU 15.6" Full HD Laptop, i7-135...
# ...                                                 ...
# 2945  Dell Latitude 7320 i5-1145G7 8GB 256GB BT5 WiF...
# 2946  NEW MSI COMPUTER Sword 15 A12UC-295 Sword15122...
# 2947  Dell Precision 5550 Workstation 15 15.6 Laptop...
# 2948  HP 15 Laptop 15.6" FHD i5-1135G7 8GB RAM 256GB...
# 2949  3 PCS Karlash 6 Column Undated Appointment Boo...
#
# ...

# %%
df = pd.read_csv("C:\\Users\\manas\\Downloads\\cleaned.csv", index_col =["Brand"])
df4
# Out:
#          Lenovo  \
# 0          Dell
# 1            HP
# 2        Lenovo
# 3        Lenovo
# 4     Microsoft
# ...         ...
# 2946       Dell
# 2947        MSI
# 2948       Dell
# 2949         HP
# 2950         HP
#
#      Lenovo ThinkPad 14” HD Laptop PC Computer Core i5 16GB RAM 256GB SSD Windows 10  \
# 0     Dell Latitude 15.6" Laptop Intel Core i5 64GB ...
# 1     NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...
# 2     2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...
# 3     2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...
# 4     Microsoft Surface Laptop 5 13.5" - 512GB SSD, ...
# ...                                                 ...
# 2946  Dell Latitude 7320 i5-1145G7 8GB 256GB BT5 WiF...
# 2947  NEW MSI COMPUTER Sword 15 A12UC-295 Sword15122...
# 2948  Dell Precision 5550 Workstation 15 15.6 Laptop...
# 2949  HP 15 Laptop 15.6" FHD i5-1135G7 8GB RAM 256GB...
# 2950  3 PCS Karlash 6 Column Undated Appointment Boo...
#
# ...

# %%
df8 = pd.read_csv("C:\\Users\\manas\\Downloads\\cleaned.csv", header =2)
df8
# Out:
#            Dell  \
# 0            HP
# 1        Lenovo
# 2        Lenovo
# 3     Microsoft
# 4        Lenovo
# ...         ...
# 2945       Dell
# 2946        MSI
# 2947       Dell
# 2948         HP
# 2949         HP
#
#      Dell Latitude 15.6" Laptop Intel Core i5 64GB RAM 2TB SSD Wi-Fi Windows 11 Pro  \
# 0     NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...
# 1     2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...
# 2     2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...
# 3     Microsoft Surface Laptop 5 13.5" - 512GB SSD, ...
# 4     Lenovo V15 G4 IRU 15.6" Full HD Laptop, i7-135...
# ...                                                 ...
# 2945  Dell Latitude 7320 i5-1145G7 8GB 256GB BT5 WiF...
# 2946  NEW MSI COMPUTER Sword 15 A12UC-295 Sword15122...
# 2947  Dell Precision 5550 Workstation 15 15.6 Laptop...
# 2948  HP 15 Laptop 15.6" FHD i5-1135G7 8GB RAM 256GB...
# 2949  3 PCS Karlash 6 Column Undated Appointment Boo...
#
# ...

# %%
df = pd.read_csv("C:\\Users\\manas\\Downloads\\cleaned.csv", index_col =["Brand"])
df
# Out:
#                                       Product_Description  Screen_Size RAM  \
# Brand
# Lenovo  Lenovo ThinkPad 14” HD Laptop PC Computer Core...         14.0  16
# Dell    Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6  64
# HP      NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...         15.6   8
# Lenovo  2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...         15.6  Up
# Lenovo  2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...         15.6  16
# ...                                                   ...          ...  ..
# Dell    Dell Latitude 7320 i5-1145G7 8GB 256GB BT5 WiF...         13.3   8
# MSI     NEW MSI COMPUTER Sword 15 A12UC-295 Sword15122...         15.6   8
# Dell    Dell Precision 5550 Workstation 15 15.6 Laptop...         15.6   8
# HP      HP 15 Laptop 15.6" FHD i5-1135G7 8GB RAM 256GB...         15.6   8
# HP      3 PCS Karlash 6 Column Undated Appointment Boo...         14.0   8
#
#                       Processor                      GPU  \
# ...

# %%
df_1 = pd.read_csv("C:\\Users\\manas\\Downloads\\cleaned.csv", names =["col1","col2","col3","col4","col5"])
df_1
# Out:
#                                                                                                                       col1  \
# Brand  Product_Description                                Screen_Size RAM Processor                                    GPU
# Lenovo Lenovo ThinkPad 14” HD Laptop PC Computer Core ... 14          16  Intel Core i5 7th Gen.     Intel HD Graphics 520
# Dell   Dell Latitude 15.6" Laptop Intel Core i5 64GB R... 15.6        64  Intel Core i5 8th Gen.    Intel UHD Graphics 620
# HP     NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB R... 15.6        8   Intel Core i5 11th Gen.   Intel Iris Xe Graphics
# Lenovo 2024 Lenovo Ideapad Laptop 15 FHD Touch Intel i... 15.6        Up  Intel Core i5 11th Gen.   Intel Iris Xe Graphics
# ...                                                                                                                    ...
# ...
