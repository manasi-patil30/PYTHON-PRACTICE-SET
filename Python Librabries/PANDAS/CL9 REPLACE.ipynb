# %% [markdown]
# # REPLACE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\manas\Downloads\cleaned.csv")
df
# Out:
#        Brand                                Product_Description  Screen_Size  \
# 0     Lenovo  Lenovo ThinkPad 14” HD Laptop PC Computer Core...         14.0
# 1       Dell  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6
# 2         HP  NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...         15.6
# 3     Lenovo  2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...         15.6
# 4     Lenovo  2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...         15.6
# ...      ...                                                ...          ...
# 2947    Dell  Dell Latitude 7320 i5-1145G7 8GB 256GB BT5 WiF...         13.3
# 2948     MSI  NEW MSI COMPUTER Sword 15 A12UC-295 Sword15122...         15.6
# 2949    Dell  Dell Precision 5550 Workstation 15 15.6 Laptop...         15.6
# 2950      HP  HP 15 Laptop 15.6" FHD i5-1135G7 8GB RAM 256GB...         15.6
# 2951      HP  3 PCS Karlash 6 Column Undated Appointment Boo...         14.0
#
# ...

# %%
df1 = df.head(25)
df1
# Out:
#         Brand                                Product_Description  Screen_Size  \
# 0      Lenovo  Lenovo ThinkPad 14” HD Laptop PC Computer Core...         14.0
# 1        Dell  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6
# 2          HP  NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...         15.6
# 3      Lenovo  2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...         15.6
# 4      Lenovo  2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...         15.6
# 5   Microsoft  Microsoft Surface Laptop 5 13.5" - 512GB SSD, ...         13.5
# 6      Lenovo  Lenovo V15 G4 IRU 15.6" Full HD Laptop, i7-135...         15.6
# 7        Dell  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6
# 8   Microsoft  Microsoft Surface Laptop 2 -8th Gen - i5 - 1.7...         13.5
# 9      Lenovo  Lenovo ThinkPad T470 14' LCD i5 Laptop PC 16GB...         14.0
# 10     Lenovo  Lenovo ThinkPad P51 15.6" Laptop i7 NVIDIA 256...         15.6
# ...

# %%
df1.replace(to_replace = "Lenovo", value= "Python")       # Give Replace using for replace the name and also give which data replace
# Out:
#         Brand                                Product_Description  Screen_Size  \
# 0      Python  Lenovo ThinkPad 14” HD Laptop PC Computer Core...         14.0
# 1        Dell  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6
# 2          HP  NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...         15.6
# 3      Python  2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...         15.6
# 4      Python  2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...         15.6
# 5   Microsoft  Microsoft Surface Laptop 5 13.5" - 512GB SSD, ...         13.5
# 6      Python  Lenovo V15 G4 IRU 15.6" Full HD Laptop, i7-135...         15.6
# 7        Dell  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6
# 8   Microsoft  Microsoft Surface Laptop 2 -8th Gen - i5 - 1.7...         13.5
# 9      Python  Lenovo ThinkPad T470 14' LCD i5 Laptop PC 16GB...         14.0
# 10     Python  Lenovo ThinkPad P51 15.6" Laptop i7 NVIDIA 256...         15.6
# ...

# %%
df1.replace("[A-Za-z]","MANASI",regex = True)  # Replace using regex expression
# Out:
#                                                 Brand  \
# 0                MANASIMANASIMANASIMANASIMANASIMANASI
# 1                            MANASIMANASIMANASIMANASI
# 2                                        MANASIMANASI
# 3                MANASIMANASIMANASIMANASIMANASIMANASI
# 4                MANASIMANASIMANASIMANASIMANASIMANASI
# 5   MANASIMANASIMANASIMANASIMANASIMANASIMANASIMANA...
# 6                MANASIMANASIMANASIMANASIMANASIMANASI
# 7                            MANASIMANASIMANASIMANASI
# 8   MANASIMANASIMANASIMANASIMANASIMANASIMANASIMANA...
# 9                MANASIMANASIMANASIMANASIMANASIMANASI
# 10               MANASIMANASIMANASIMANASIMANASIMANASI
# 11                           MANASIMANASIMANASIMANASI
# 12                           MANASIMANASIMANASIMANASI
# 13                           MANASIMANASIMANASIMANASI
# 14                           MANASIMANASIMANASIMANASI
# 15                           MANASIMANASIMANASIMANASI
# ...

# %%
df1.replace({"Brand" : '[A-Z]'}, 45 ,regex= True)   # Replace columns data
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17320\3071518513.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1.replace({"Brand" : '[A-Z]'}, 45 ,regex= True)   # Replace columns data
#     Brand                                Product_Description  Screen_Size  \
# 0      45  Lenovo ThinkPad 14” HD Laptop PC Computer Core...         14.0
# 1      45  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6
# 2      45  NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...         15.6
# 3      45  2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...         15.6
# 4      45  2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...         15.6
# 5      45  Microsoft Surface Laptop 5 13.5" - 512GB SSD, ...         13.5
# ...

# %%
df1.replace(8, method="ffill")        # Fill Data Using forward and backward values
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_17320\3253858846.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   df1.replace(8, method="ffill")
#         Brand                                Product_Description  Screen_Size  \
# 0      Lenovo  Lenovo ThinkPad 14” HD Laptop PC Computer Core...         14.0
# 1        Dell  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6
# 2          HP  NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...         15.6
# 3      Lenovo  2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...         15.6
# 4      Lenovo  2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...         15.6
# 5   Microsoft  Microsoft Surface Laptop 5 13.5" - 512GB SSD, ...         13.5
# 6      Lenovo  Lenovo V15 G4 IRU 15.6" Full HD Laptop, i7-135...         15.6
# 7        Dell  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6
# ...
